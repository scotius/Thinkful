# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df = pd.read_csv('Unemployment.csv')

# %%
df.describe()
# Out:
#        Unemployment_rate_2007  Unemployment_rate_2008  Unemployment_rate_2009  \
# count               53.000000               53.000000               53.000000
# mean                 4.503774                5.486792                8.637736
# std                  1.335890                1.475445                2.152925
# min                  2.600000                3.100000                4.100000
# 25%                  3.700000                4.600000                7.200000
# 50%                  4.500000                5.400000                8.300000
# 75%                  5.000000                6.300000               10.300000
# max                 11.200000               11.800000               15.300000
#
#        Unemployment_rate_2010  Unemployment_rate_2011  Unemployment_rate_2012  \
# count               53.000000               53.000000               53.000000
# mean                 8.920755                8.326415                7.516981
# ...

# %%
df.set_index("State", inplace=True)

# %%
df.index
# Out:
# Index(['AL', 'AK', 'AZ', 'AR', 'CA', 'Co', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI',
#        'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN',
#        'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH',
#        'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA',
#        'WV', 'WI', 'WY', 'PR', 'US'],
#       dtype='object', name='State')

# %%
df.head()
# Out:
#         Area_name labor_force_2007  Employed_2007   Unemployed_2007   \
# State
# AL        Alabama        2,175,612       2,089,127            86,485
# AK         Alaska          350,785         328,579            22,206
# AZ        Arizona        3,034,016       2,917,117           116,899
# AR       Arkansas        1,369,284       1,296,572            72,712
# CA     California       17,893,080      16,931,590           961,490
#
#        Unemployment_rate_2007 labor_force_2008  Employed_2008   \
# State
# AL                        4.0        2,176,489       2,053,477
# AK                        6.3          356,109         332,285
# AZ                        3.9        3,104,863       2,913,903
# AR                        5.3        1,375,257       1,300,017
# CA                        5.4       18,178,123      16,854,482
#
#        Unemployed_2008   Unemployment_rate_2008 labor_force_2009  \
# State
# AL              123,012                     5.7          2162999
# ...

# %%
df.columns
# Out:
# Index(['Area_name', 'labor_force_2007', ' Employed_2007 ', ' Unemployed_2007 ',
#        'Unemployment_rate_2007', 'labor_force_2008', ' Employed_2008 ',
#        ' Unemployed_2008 ', 'Unemployment_rate_2008', 'labor_force_2009',
#        'Employed_2009', 'Unemployed_2009', 'Unemployment_rate_2009',
#        'labor_force_2010', ' Employed_2010 ', ' Unemployed_2010 ',
#        'Unemployment_rate_2010', 'labor_force_2011', ' Employed_2011 ',
#        ' Unemployed_2011 ', 'Unemployment_rate_2011', 'labor_force_2012',
#        ' Employed_2012 ', ' Unemployed_2012 ', 'Unemployment_rate_2012',
#        'labor_force_2013', ' Employed_2013 ', ' Unemployed_2013 ',
#        'Unemployment_rate_2013', 'labor_force_2014', ' Employed_2014 ',
#        ' Unemployed_2014 ', 'Unemployment_rate_2014', 'labor_force_2015',
#        ' Employed_2015 ', ' Unemployed_2015 ', 'Unemployment_rate_2015',
#        'labor_force_2016', ' Employed_2016 ', ' Unemployed_2016 ',
# ...

# %%
df[['labor_force_2007','labor_force_2008','labor_force_2009','labor_force_2010','labor_force_2011']]
# Out:
#       labor_force_2007 labor_force_2008 labor_force_2009 labor_force_2010  \
# State
# AL           2,175,612        2,176,489          2162999        2,196,042
# AK             350,785          356,109           359647          361,913
# AZ           3,034,016        3,104,863          3128110        3,089,705
# AR           1,369,284        1,375,257          1358911        1,353,338
# CA          17,893,080       18,178,123         18215140       18,336,271
# Co           2,664,677        2,716,625          2722982        2,724,417
# CT           1,856,209        1,881,454          1891077        1,911,712
# DE             443,573          447,041           437500          434,419
# DC             322,237          330,544           335672          346,065
# FL           9,157,124        9,215,524          9094825        9,212,066
# GA           4,815,818        4,879,253          4787749        4,696,676
# HI             638,395          639,691           631690          647,249
# ...
