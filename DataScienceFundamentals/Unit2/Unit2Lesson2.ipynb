# %%
import pandas as pd

# %%
df1 = pd.read_csv('Unemployment.csv')

# %%
df1
# Out:
#    State             Area_name  Civilian_labor_force_2007   Employed_2007   \
# 0     AL               Alabama                  2,175,612       2,089,127
# 1     AK                Alaska                    350,785         328,579
# 2     AZ               Arizona                  3,034,016       2,917,117
# 3     AR              Arkansas                  1,369,284       1,296,572
# 4     CA            California                 17,893,080      16,931,590
# 5     Co              Colorado                  2,664,677       2,565,218
# 6     CT           Connecticut                  1,856,209       1,773,159
# 7     DE              Delaware                    443,573         428,312
# 8     DC  District of Columbia                    322,237         304,426
# 9     FL               Florida                  9,157,124       8,789,770
# 10    GA               Georgia                  4,815,818       4,597,640
# 11    HI                Hawaii                    638,395         620,535
# ...

# %%
df2 = pd.read_csv('Education.csv')

# %%
df2
# Out:
#     State             Area name Less than a high school diploma, 1970  \
# 0      AL               Alabama                             1,062,306
# 1      AK                Alaska                                44,994
# 2      AZ               Arizona                               383,873
# 3      AR              Arkansas                               635,149
# 4      CA            California                             4,062,367
# 5      CO              Colorado                               411,837
# 6      CT           Connecticut                               740,830
# 7      DE              Delaware                               130,463
# 8      DC  District of Columbia                               189,720
# 9      FL               Florida                             1,882,537
# 10     GA               Georgia                             1,399,175
# 11     HI                Hawaii                               146,701
# ...
