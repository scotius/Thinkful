# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv('plane_crashes_data.csv', index)

# %%
df.head()
# Out:
#    month hour  year                         location  \
# 0      1   12  1950              Near Vacas, Bolivia
# 1      3   20  1950           Minneapolis, Minnesota
# 2      3   14  1950  Llandow Airport, Cardiff, Wales
# 3      4   23  1950               Near Atsugi, Japan
# 4      5   20  1950    Lagens Air Force Base, Azores
#
#                         operator                          route  \
# 0  Military - Bolivian Air Force      Valle grande - Cochabamba
# 1      Northwest Orient Airlines  Rochester Minn. - Minneapolis
# 2                Fairflight Ltd.               Llandow - Dublin
# 3      Military - U.S. Air Force            Philippines - Japan
# 4      Military - U.S. Air Force              Bermuda - England
#
#                type  aboard  fatalities  \
# 0      Douglas C-47      32          32
# 1        Martin 202      13          13
# 2  Avro 689 Tudor 5      83          80
# 3     Douglas C-54D      35          35
# 4       Boeing B-29      16          16
#
# ...

# %%
df['fatalities'].plot()

# %%
months = df.groupby('month')

# %%
months.describe()
# Out:
#       aboard                                                     fatalities  \
#        count       mean        std  min  25%   50%    75%    max      count
# month
# 1      255.0  28.745098  38.833504  1.0  4.0  15.0  35.00  213.0      255.0
# 2      209.0  37.976077  55.470144  1.0  4.0  15.0  49.00  356.0      209.0
# 3      251.0  31.729084  56.190518  1.0  5.0  14.0  38.00  644.0      251.0
# 4      204.0  30.715686  46.521117  1.0  5.0  15.5  31.25  330.0      204.0
# 5      181.0  32.149171  45.389975  1.0  5.0  13.0  37.00  271.0      181.0
# 6      202.0  37.767327  51.884394  1.0  5.0  18.0  49.25  329.0      202.0
# 7      234.0  40.051282  64.126129  1.0  5.0  14.0  49.00  517.0      234.0
# 8      239.0  40.372385  65.210708  1.0  4.0  15.0  46.50  524.0      239.0
# 9      228.0  39.868421  56.895842  0.0  6.0  16.5  53.25  394.0      228.0
# 10     224.0  28.758929  39.606754  1.0  4.0  11.0  34.00  226.0      224.0
# ...

# %%
df[['aboard','fatalities']].plot()

# %%
df.dtypes
# Out:
# month          int64
# hour          object
# location      object
# operator      object
# route         object
# type          object
# aboard         int64
# fatalities     int64
# summary       object
# dtype: object

# %%
df.describe()
# Out:
#              month       aboard   fatalities
# count  2709.000000  2709.000000  2709.000000
# mean      6.554079    35.817276    25.816537
# std       3.532468    54.306779    42.599461
# min       1.000000     0.000000     0.000000
# 25%       3.000000     5.000000     3.000000
# 50%       7.000000    15.000000     9.000000
# 75%      10.000000    44.000000    29.000000
# max      12.000000   644.000000   583.000000

# %%
df1 = pd.read_csv('plane_crashes_data.csv')

# %%
df1.head()
# Out:
#    month hour  year                         location  \
# 0      1   12  1950              Near Vacas, Bolivia
# 1      3   20  1950           Minneapolis, Minnesota
# 2      3   14  1950  Llandow Airport, Cardiff, Wales
# 3      4   23  1950               Near Atsugi, Japan
# 4      5   20  1950    Lagens Air Force Base, Azores
#
#                         operator                          route  \
# 0  Military - Bolivian Air Force      Valle grande - Cochabamba
# 1      Northwest Orient Airlines  Rochester Minn. - Minneapolis
# 2                Fairflight Ltd.               Llandow - Dublin
# 3      Military - U.S. Air Force            Philippines - Japan
# 4      Military - U.S. Air Force              Bermuda - England
#
#                type  aboard  fatalities  \
# 0      Douglas C-47      32          32
# 1        Martin 202      13          13
# 2  Avro 689 Tudor 5      83          80
# 3     Douglas C-54D      35          35
# 4       Boeing B-29      16          16
#
# ...

# %%
#sort and sum fatalities and number of passengers for each year

# %%
df2 = df1.groupby('year', as_index=False)[['fatalities','aboard']].sum()

# %%
df2.head()
# Out:
#    year  fatalities  aboard
# 0  1950         809     931
# 1  1951         656     735
# 2  1952         744     950
# 3  1953         776     954
# 4  1954         482     616

# %%
ax = df2.plot.bar(x='year', y='fatalities', figsize=(20,10), color = 'blue')

# %%
df2.plot(x="year", y=["fatalities", "aboard"], kind="bar", figsize = (20,10))
